# %%
import pandas as pd

file1 =r"C:\Users\Sharlmagne Henry\Documents\Data Analytics\WHO COVID-19 Insights\WHO COVID-19 Data\WHO-COVID-19-global-data.csv"
file2 = r"C:\Users\Sharlmagne Henry\Documents\Data Analytics\WHO COVID-19 Insights\WHO COVID-19 Data\WHO-COVID-19-global-table-data.csv"

df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2, index_col=False)

# %%
df2
# Out:
#                                       Name       WHO Region  \
# 0                                   Global              NaN
# 1                 United States of America         Americas
# 2                                    India  South-East Asia
# 3                                   Brazil         Americas
# 4                                   France           Europe
# ..                                     ...              ...
# 233                       Pitcairn Islands  Western Pacific
# 234  Democratic People's Republic of Korea  South-East Asia
# 235                           Saint Helena           Africa
# 236                                Tokelau  Western Pacific
# 237                           Turkmenistan           Europe
#
#      Cases - cumulative total  Cases - cumulative total per 100000 population  \
# 0                   599825400                                     7695.455696
# 1                    93060268                                    28114.659000
# ...
